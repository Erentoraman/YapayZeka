# %% [markdown]
# Yapay Zeka Kütüphaneleri:
#
# "Scikit-Learn" kütüphanesi:
#
# "Tensorflow" kütüphanesi:
#
# "Pytorch" kütüphanesi:
#
# "Keras" kütüphanesi:
#
# Eren Toraman 25.10.2024

# %%
import sys # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.chdir('/content/drive/My Drive/YapayZeka')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/YapayZeka

# %% [markdown]
# PYTHON PROGRAMLAMA DİLİ KÜTÜPHANELERİ - Scikit-Learn, TensorFlow, PyTorch, Keras

# %%
# CPU ve GPU teknolojisinin kullanımına göre olması gereken veri sayısı tablosu

import pandas as pd

tablo = {
    "Aralık": ["Küçük ölçekli", "Orta ölçekli", "Büyük ölçekli", "Hiper ölçekli", "Exascale"],
    "Veri Sayısı": ["100 - 10,000", "10,000 - 100,000", "100,000 - Milyon",  "Milyon - Milyar", "Milyar - Trilyon"],
    "CPU": ["Evet", "Evet", "Opsiyonel", "Hayır", "Hayır"],
    "GPU": ["Hayır", "Opsiyonel", "Evet", "Evet", "Evet"]
}

print(pd.DataFrame(tablo))
# Out:
#           Aralık       Veri Sayısı        CPU        GPU
# 0  Küçük ölçekli      100 - 10,000       Evet      Hayır
# 1   Orta ölçekli  10,000 - 100,000       Evet  Opsiyonel
# 2  Büyük ölçekli  100,000 - Milyon  Opsiyonel       Evet
# 3  Hiper ölçekli   Milyon - Milyar      Hayır       Evet
# 4       Exascale  Milyar - Trilyon      Hayır       Evet

# %% [markdown]
# Kütüphane Kurulumunda dikkat edilmesi gereken en önemli konu:
# Genel kullanım bakımından python kütüphanesi kurucağımız zaman dikkat edilmesi gereken iki yapı bulunmaktadır. Bu yapılar "pip" ve "pip3"'tür.
#
# pip yapısı -> Python 2.x sürümlerini destekler.
#
# pip3 yapısı -> Python 3.x sürümlerini destekler.

# %%
import pandas as pd

# True Positive (TP), True Negative (TN), False Positive (FP), False Negative (FN)
matris_bilgisi = {
    "Gerçek Pozitif": ["Doğru Pozitif (TP)", "Yanlış Negatif (FN)"],
    "Gerçek Negatif": ["Yanlış Pozitif (FP)", "Doğru Negatif (TN)"]
}

# DataFrame oluşturma
matris = pd.DataFrame(matris_bilgisi, index=["Tahmin Pozitif", "Tahmin Negatif"])

# Tabloyu gösterme
print(matris)
# Out:
#                      Gerçek Pozitif       Gerçek Negatif
# Tahmin Pozitif   Doğru Pozitif (TP)  Yanlış Pozitif (FP)
# Tahmin Negatif  Yanlış Negatif (FN)   Doğru Negatif (TN)

# %% [markdown]
# Karmaşıklık matrisinden sistemin doğruluğunu bulacağımız formül ->
#
# Dogruluk = TP+TN+FP+FN / TP+TN 'dir.
#
# Örneğin: TP = 50, TN = 40, FP = 5, FN = 5 ise; Dogruluk = 50 + 40 + 5 + 5 / 50 + 40 --> 0.9 -> % 90 olarak hesaplanmaktadır.
#
# %90 Model Doğruluk Oranı - %10 Modelin Hata Oranı 'dır.
#
# Hata oranını azaltmak için->
#
# - Modelin iyileştirilmesi,
# - Veri sayısının arttırılması,
# - Eğitim adım sayısının değiştirilmesi,
# - Veri seti içerisindeki farklı değişlenlerin
# - özelliklerin algoritmaya dahil edilmesi.

# %%
# Scikit-Learn kütüphanesinin sisteme dahil edilmesi ve veri setinin işleme alınması

# !pip install -U scikit-learn

# %% [markdown]
# Scikit-Learn kütüphanesi: Makine öğrenimi kütüphanesidir. Veri madenciliği ve veri analizi için geniş bir araç seti sunar. Scikit-Learn, denetimli ve denetimsiz öğrenme, model seçimi, ön işleme, boyut indirgeme, kümeleme ve daha birçok makine öğrenimi görevini destekler.
#
# Temel Özellikleri:
# - Kullanımı Kolay: Basit ve anlaşılır bir API yapısına sahiptir.
# - Zengin Algoritma Desteği: Regresyon, sınıflandırma, kümeleme gibi birçok makine öğrenimi algoritmasını içerir.
# - Ön İşleme Araçları: Verileri ölçeklendirme, normalleştirme ve dönüştürme gibi işlemleri kolayca yapmanızı sağlar.
# -Model Değerlendirme: Modelin performansını değerlendirmek için çeşitli metrikler ve çapraz doğrulama yöntemleri sunar.
# - Veri Setleri: Örnek veri setleri ile birlikte gelir, bu da öğrenme ve deneme sürecini kolaylaştırır.
#
# Kullanım Alanları:
# - Öngörücü modelleme
# - Sınıflandırma
# - Kümeleme
# - Veri madenciliği
# - Öneri sistemleri
#
# !pip install -U scikit-learn

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

# California Housing veri setini yükleme
housing = fetch_california_housing()

# Özellikleri ve hedef değişkeni almak
X = housing.data  # Bağımsız değişkenler (özellikler)
y = housing.target  # Bağımlı değişken (fiyatlar)

# Verileri bir DataFrame'e dönüştürme
df = pd.DataFrame(X, columns=housing.feature_names)
df['PRICE'] = y

# İlk birkaç satırı görüntüleme
print(df.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  PRICE
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# California Housing veri setini yükleme
housing = fetch_california_housing()
df = pd.DataFrame(housing.data, columns=housing.feature_names)
df['PRICE'] = housing.target

# Özellikler ve hedef değişkeni ayırma
X = df.drop('PRICE', axis=1)
y = df['PRICE']

# Veri setini bölme
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Model oluşturma
model = LinearRegression()
model.fit(X_train, y_train)

# Tahmin yapma
predictions = model.predict(X_test)
print("Tahmin Sonucları: ", predictions[:5])
print("Gerçek Değerler: ", y_test[:5].values)

# Sistemin Ortalama Hatası (MSE)
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error (MSE) Sonucu:", mse)

# Sistemin R-kare Hatası (R²)
r2 = r2_score(y_test, predictions)
print("R-squared (R²) Sonucu:", r2)
# Out:
# Tahmin Sonucları:  [0.72604907 1.76743383 2.71092161 2.83514727 2.60695807]
# Gerçek Değerler:  [0.477   0.458   5.00001 2.186   2.78   ]
# Mean Squared Error (MSE) Sonucu: 0.5305677824766758
# R-squared (R²) Sonucu: 0.595770232606166

# %%
# TensorFlow kütüphanesinin sisteme dahil edilmesi ve veri setinin işleme alınması

# !pip install pydot
# !apt-get install graphviz
# !pip install tensorflow

# Bu iki kütüphane ile oluşturulan yapay zeka modelinin yapısını çıktı alabileceğiz.
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ...

# %% [markdown]
# TensorFlow kütüphanesi: Google tarafından geliştirilen açık kaynaklı bir makine öğrenimi ve derin öğrenme kütüphanesidir. Özellikle büyük ölçekli veri işleme ve karmaşık hesaplamalar için tasarlanmıştır. TensorFlow, hem eğitim hem de üretim ortamlarında model geliştirme, eğitim ve dağıtım süreçlerini kolaylaştırır.
#
# Temel Özellikleri:
# - Veri Akışı Grafikleri: TensorFlow, hesaplamaları grafikler aracılığıyla temsil eder; bu sayede karmaşık matematiksel işlemleri daha etkili bir şekilde gerçekleştirebilir.
# - Çoklu Platform Desteği: TensorFlow, CPU, GPU ve TPU üzerinde çalışabilir, bu da performansı artırır.
# - Yüksek Seviye API'ler: Kütüphane, Keras gibi yüksek seviye API'lerle birlikte gelir, bu da model oluşturmayı ve eğitmeyi kolaylaştırır.
# - Modüler Yapı: TensorFlow, farklı uygulama alanlarına yönelik modüler bir yapıya sahiptir.
# - Geniş Kullanım Alanları: Görüntü işleme, doğal dil işleme, zaman serisi analizi gibi birçok alanda kullanılabilir.
#
# Kullanım Alanları:
# - Derin öğrenme modelleri (sinir ağları)
# - Görüntü ve ses tanıma
# - Doğal dil işleme
# - Öneri sistemleri
# - Oyun ve simülasyon
#
# !pip install tensorflow
#
# !pip install tensorflow-gpu

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import plot_model

(x_train, y_train), (x_test, y_test) = mnist.load_data() # MNIST veri setini yükleme
x_train, x_test = x_train / 255.0, x_test / 255.0
# !pwd
# Out:
# /content/drive/MyDrive/YapayZeka

# %% [markdown]
# Yapay zeka modeli oluşturmada aşamalar;

# %%
model = models.Sequential([ # Modeli oluşturma
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Modelin eğitim süreci

# %%
model.compile(optimizer='adam', # Modeli derleme
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Modelin eğitim süreci
# model eğitim işlemi --> model.fit()
# model eğitim işlemi --> model.fit(x_train, y_train, ...)
# Eğitim Adım Sayısı --> epochs=5

# %%
model.fit(x_train, y_train, epochs=5) # Modeli Eğitilmesi Adımı

# Modeli görselleştirmek ve çalışma alanına kaydetmek için plot_model kullanımı
plot_model(model, to_file='YZ_Model/yz_tensoflow_model_ciktisi.png', show_shapes=True, show_layer_names=True) # Modelin Çıktısı
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - accuracy: 0.8619 - loss: 0.4781
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - accuracy: 0.9574 - loss: 0.1457
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9689 - loss: 0.1082
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9730 - loss: 0.0870
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9766 - loss: 0.0752

# %%
# Test seti üzerinde modelin performansını değerlendirme

hata_oranı, basarı_oranı = model.evaluate(x_test, y_test, verbose=2)

print(" Modelin Doğruluk Oranı: %", basarı_oranı*100)
print(" Modelin Hata Oranı: %", hata_oranı*100)
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.9798 - loss: 0.0681
#  Modelin Doğruluk Oranı: % 97.97999858856201
#  Modelin Hata Oranı: % 6.814999133348465

# %% [markdown]
# PyTorch kütüphanesi: Derin öğrenme modelleri oluşturmak, eğitmek ve değerlendirmek için yaygın olarak kullanılır. PyTorch'un başlıca özellikleri şunlardır:
#
# Dinamik Hesap Grafiği: PyTorch, dinamik hesap grafiği ile çalışır. Bu, kullanıcıların modelin çalışma zamanında grafiği değiştirebilmelerini sağlar, bu da daha esnek ve kullanıcı dostu bir deneyim sunar.
#
# Tensor İşlemleri: PyTorch, çok boyutlu diziler (tensorlar) üzerinde verimli matematiksel işlemler yapmayı sağlar. Tensorlar, Numpy dizilerine benzer, ancak GPU desteği ile hızlandırılabilirler.
#
# Otomatik Türev Hesaplama: PyTorch, model eğitimi sırasında otomatik türev hesaplama yaparak, geri yayılım algoritmasını kolaylaştırır.
#
# Modelleme ve Eğitim Kolaylığı: PyTorch, modelin hızlı bir şekilde tanımlanmasını ve eğitilmesini sağlayan basit ve sezgisel bir API sunar.
#
# Geniş Topluluk ve Kaynaklar: PyTorch, aktif bir topluluk ve geniş bir belge ve kaynak havuzuna sahiptir. Bu da kullanıcıların öğrenmesini ve sorunları çözmesini kolaylaştırır.
#
# PyTorch, araştırmacılar ve geliştiriciler tarafından derin öğrenme uygulamaları, doğal dil işleme, görüntü işleme ve daha birçok alanda yaygın olarak kullanılmaktadır.
#
#
# !pip install torch torchvision torchaudio

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# MNIST veri setini yükleme
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_set = datasets.MNIST('./data', train=True, download=True, transform=transform)
test_set = datasets.MNIST('./data', train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=64, shuffle=False)

# Modeli oluşturma
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = Net()

# Kayıp fonksiyonu ve optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Eğitim için boş listeler tanımla
train_losses = []
train_accuracies = []

# Eğitme döngüsü
for epoch in range(50):  # 50 epoch boyunca eğit
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        # Kayıp (loss) değerini topla
        running_loss += loss.item()

        # Doğruluğu hesapla
        _, predicted = torch.max(output, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Her epoch sonunda ortalama kayıp ve doğruluk
    epoch_loss = running_loss / len(train_loader)
    epoch_accuracy = 100 * correct / total
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)

    print(f'Epoch {epoch+1}, Loss: {epoch_loss}, Accuracy: {epoch_accuracy}%')

print('Eğitim tamamlandı!')

# Eğitim sonuçlarını grafikle göster
epochs = range(1, 51)  # 50 epoch olduğu için 1'den 51'ya kadar olan epoch'lar
plt.figure(figsize=(12, 5))

# Kayıp grafiği
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, 'bo-', label='Eğitim Kaybı (Loss)')
plt.title('Eğitim Kaybı')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Doğruluk grafiği
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, 'go-', label='Eğitim Doğruluğu (Accuracy)')
plt.title('Eğitim Doğruluğu')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ...
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# ...
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 44.5MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# ...
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 2.02MB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)>
#
# ...
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 13.1MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# ...
# Failed to download (trying next):
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# MNIST veri setini yükleme
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_set = datasets.MNIST('./data', train=True, download=True, transform=transform)
test_set = datasets.MNIST('./data', train=False, transform=transform)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=64, shuffle=False)

# Modeli oluşturma
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = Net()

# Kayıp fonksiyonu ve optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Eğitim için boş listeler tanımla
train_losses = []
train_accuracies = []

# Eğitme döngüsü
for epoch in range(50):  # 50 epoch boyunca eğit
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        # Kayıp (loss) değerini topla
        running_loss += loss.item()

        # Doğruluğu hesapla
        _, predicted = torch.max(output, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    # Her epoch sonunda ortalama kayıp ve doğruluk
    epoch_loss = running_loss / len(train_loader)
    epoch_accuracy = 100 * correct / total
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)

    print(f'Epoch {epoch+1}, Loss: {epoch_loss}, Accuracy: {epoch_accuracy}%')

print('Eğitim tamamlandı!')

# Eğitim sonuçlarını grafikle göster
epochs = range(1, 51)  # 50 epoch olduğu için 1'den 51'ya kadar olan epoch'lar
plt.figure(figsize=(12, 5))

# Kayıp grafiği
plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, 'bo-', label='Eğitim Kaybı (Loss)')
plt.title('Eğitim Kaybı')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Doğruluk grafiği
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, 'go-', label='Eğitim Doğruluğu (Accuracy)')
plt.title('Eğitim Doğruluğu')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Loss: 0.7623825518052969, Accuracy: 81.11%
# Epoch 2, Loss: 0.36926133425505175, Accuracy: 89.47833333333334%
# Epoch 3, Loss: 0.3240345083653673, Accuracy: 90.515%
# Epoch 4, Loss: 0.2974388242752821, Accuracy: 91.37333333333333%
# Epoch 5, Loss: 0.2769226873003598, Accuracy: 92.04166666666667%
# Epoch 6, Loss: 0.2591897115778567, Accuracy: 92.53666666666666%
# Epoch 7, Loss: 0.24197948467470945, Accuracy: 93.02166666666666%
# Epoch 8, Loss: 0.22606436681868172, Accuracy: 93.58166666666666%
# Epoch 9, Loss: 0.21224045442111455, Accuracy: 94.005%
# Epoch 10, Loss: 0.19981746186516178, Accuracy: 94.33833333333334%
# Epoch 11, Loss: 0.18795005239244464, Accuracy: 94.66333333333333%
# Epoch 12, Loss: 0.1774057619678758, Accuracy: 95.02666666666667%
# Epoch 13, Loss: 0.1678989698756923, Accuracy: 95.3%
# Epoch 14, Loss: 0.15923057835914498, Accuracy: 95.48666666666666%
# Epoch 15, Loss: 0.15131756474277866, Accuracy: 95.72166666666666%
# ...

# %% [markdown]
# Keras kütüphanesi: derin öğrenme modelleri oluşturmak ve eğitmek için kullanılan yüksek seviyeli bir açık kaynak kütüphanedir. Python dilinde yazılmıştır ve TensorFlow, Microsoft Cognitive Toolkit (CNTK) veya Theano gibi alt kütüphanelerin üstünde çalışabilir.
#
# Keras'ın Özellikleri:
# Kullanım Kolaylığı: Kullanıcı dostu API'si sayesinde hızlı bir şekilde modeller oluşturup eğitebilirsiniz.
# Modülerlik: Keras, model bileşenlerini (katmanlar, optimizatörler, kayıp fonksiyonları vb.) kolayca birleştirmenize olanak tanır.
# Esneklik: Derin öğrenme modellerinin hızlı prototiplenmesi için esnek bir yapı sunar.
# Destek: Geniş bir topluluk ve bolca dökümantasyon ile desteklenmektedir.
# Keras ile Yapılabilecekler:
# Yapay sinir ağları (ANN)
# Konvolüsyonel sinir ağları (CNN)
# Tekrarlayan sinir ağları (RNN)
# Transfer öğrenme
#
#
# !pip install keras

# %%
# !pip install keras
